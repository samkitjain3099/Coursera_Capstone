# %% [markdown]
# # **A program For Photographers Event**

# %% [markdown]
# ## **Introduction**

# %% [markdown]
# ABC is a company based in Toronto for organizing events, currently it works on a project to organize an event for 5 days for a group of photographers from all over the world.The company has to put a good program, including a hotel of residence, a hall for meetings,
# places of landscape to visit, stores for shopping, restaurants and cafes. So the company’s purpose is to make a list of places of landscape in Toronto, including the nearest restaurants, cafes, and shopping stores for each place.

# %% [markdown]
# ## **Data Description**

# %% [markdown]
# The data used in this project is provided by Foursquare location data. The data are grouped by landscape area, and each area included the information about this area and all information about restaurants, cafes, and stores which in this area.

# %% [markdown]
# ## **Table of contents**

# %% [markdown]
# #### 01- Import Libraries
# #### 02- Define Foursquare Credentials
# #### 03- Search for Hotels
# #### 04- Search for Hotels & clean dataframe
# #### 05- Search for Parks & clean dataframe
# #### 06- Search for Restaurants & clean dataframe
# #### 07- Search for Cafeteria & clean dataframe
# #### 08- Search for Shopping Stores & clean dataframe
# #### 09- Generate map to visualize hotels, shopping stores and Cafeteria and how they cluster together
# #### 10- Generate map to visualize Park, Restaurant and Cafeteria and how they cluster together

# %% [markdown]
# ## **Import Libraries**

# %%
import requests # to handle requests
import pandas as pd # for data analsysis
import numpy as np # to handle data in a vectorized manner

# !conda install -c conda-forge geopy --yes 
from geopy.geocoders import Nominatim # module to convert an address into latitude and longitude values

# libraries for displaying images
from IPython.display import Image 
from IPython.core.display import HTML 
    
#tranforming json file into a pandas dataframe library
from pandas.io.json import json_normalize

# !conda install -c conda-forge folium=0.5.0 --yes
import folium # plotting library
# Out:
# Collecting package metadata (current_repodata.json): done
# Solving environment: done
#
# ## Package Plan ##
#
#   environment location: /home/jupyterlab/conda/envs/python
#
#   added / updated specs:
#     - geopy
#
#
# The following packages will be downloaded:
#
#     package                    |            build
#     ---------------------------|-----------------
#     geographiclib-1.50         |             py_0          34 KB  conda-forge
#     geopy-1.21.0               |             py_0          58 KB  conda-forge
#     openssl-1.1.1g             |       h516909a_0         2.1 MB  conda-forge
#     ------------------------------------------------------------
#                                            Total:         2.2 MB
#
# The following NEW packages will be INSTALLED:
#
#   geographiclib      conda-forge/noarch::geographiclib-1.50-py_0
#   geopy              conda-forge/noarch::geopy-1.21.0-py_0
#
# The following packages will be UPDATED:
#
#   openssl                                 1.1.1f-h516909a_0 --> 1.1.1g-h516909a_0
#
#
#
# Downloading and Extracting Packages
# openssl-1.1.1g       | 2.1 MB    | ##################################### | 100%
# geopy-1.21.0         | 58 KB     | ##################################### | 100%
# geographiclib-1.50   | 34 KB     | ##################################### | 100%
# Preparing transaction: done
# Verifying transaction: done
# Executing transaction: done
# Collecting package metadata (current_repodata.json): done
# Solving environment: failed with initial frozen solve. Retrying with flexible solve.
# Collecting package metadata (repodata.json): done
# Solving environment: done
#
# ## Package Plan ##
#
#   environment location: /home/jupyterlab/conda/envs/python
#
#   added / updated specs:
#     - folium=0.5.0
#
#
# The following packages will be downloaded:
#
#     package                    |            build
#     ---------------------------|-----------------
#     altair-4.1.0               |             py_1         614 KB  conda-forge
#     branca-0.4.0               |             py_0          26 KB  conda-forge
#     brotlipy-0.7.0             |py36h8c4c3a4_1000         346 KB  conda-forge
#     chardet-3.0.4              |py36h9f0ad1d_1006         188 KB  conda-forge
#     cryptography-2.8           |   py36h45558ae_2         628 KB  conda-forge
#     folium-0.5.0               |             py_0          45 KB  conda-forge
#     pandas-1.0.3               |   py36h830a2c2_1        11.1 MB  conda-forge
#     pysocks-1.7.1              |   py36h9f0ad1d_1          27 KB  conda-forge
#     toolz-0.10.0               |             py_0          46 KB  conda-forge
#     urllib3-1.25.9             |             py_0          92 KB  conda-forge
#     vincent-0.4.4              |             py_1          28 KB  conda-forge
#     ------------------------------------------------------------
#                                            Total:        13.1 MB
#
# The following NEW packages will be INSTALLED:
#
#   altair             conda-forge/noarch::altair-4.1.0-py_1
#   attrs              conda-forge/noarch::attrs-19.3.0-py_0
#   branca             conda-forge/noarch::branca-0.4.0-py_0
#   brotlipy           conda-forge/linux-64::brotlipy-0.7.0-py36h8c4c3a4_1000
#   chardet            conda-forge/linux-64::chardet-3.0.4-py36h9f0ad1d_1006
#   cryptography       conda-forge/linux-64::cryptography-2.8-py36h45558ae_2
#   entrypoints        conda-forge/linux-64::entrypoints-0.3-py36h9f0ad1d_1001
#   folium             conda-forge/noarch::folium-0.5.0-py_0
#   idna               conda-forge/noarch::idna-2.9-py_1
#   importlib-metadata conda-forge/linux-64::importlib-metadata-1.6.0-py36h9f0ad1d_0
#   importlib_metadata conda-forge/noarch::importlib_metadata-1.6.0-0
#   jinja2             conda-forge/noarch::jinja2-2.11.2-pyh9f0ad1d_0
#   jsonschema         conda-forge/linux-64::jsonschema-3.2.0-py36h9f0ad1d_1
#   markupsafe         conda-forge/linux-64::markupsafe-1.1.1-py36h8c4c3a4_1
#   pandas             conda-forge/linux-64::pandas-1.0.3-py36h830a2c2_1
#   pyopenssl          conda-forge/noarch::pyopenssl-19.1.0-py_1
#   pyrsistent         conda-forge/linux-64::pyrsistent-0.16.0-py36h8c4c3a4_0
#   pysocks            conda-forge/linux-64::pysocks-1.7.1-py36h9f0ad1d_1
#   pytz               conda-forge/noarch::pytz-2019.3-py_0
#   requests           conda-forge/noarch::requests-2.23.0-pyh8c360ce_2
#   toolz              conda-forge/noarch::toolz-0.10.0-py_0
#   urllib3            conda-forge/noarch::urllib3-1.25.9-py_0
#   vincent            conda-forge/noarch::vincent-0.4.4-py_1
#   zipp               conda-forge/noarch::zipp-3.1.0-py_0
#
#
#
# Downloading and Extracting Packages
# pysocks-1.7.1        | 27 KB     | ##################################### | 100%
# cryptography-2.8     | 628 KB    | ##################################### | 100%
# toolz-0.10.0         | 46 KB     | ##################################### | 100%
# chardet-3.0.4        | 188 KB    | ##################################### | 100%
# folium-0.5.0         | 45 KB     | ##################################### | 100%
# urllib3-1.25.9       | 92 KB     | ##################################### | 100%
# brotlipy-0.7.0       | 346 KB    | ##################################### | 100%
# pandas-1.0.3         | 11.1 MB   | ##################################### | 100%
# altair-4.1.0         | 614 KB    | ##################################### | 100%
# branca-0.4.0         | 26 KB     | ##################################### | 100%
# vincent-0.4.4        | 28 KB     | ##################################### | 100%
# Preparing transaction: done
# Verifying transaction: done
# Executing transaction: done

# %% [markdown]
# ## **Define Foursquare Credentials**

# %%
ClIENT_ID = '4FQQJE2LMGVLERRRE2BOFR1LQQR5ZEHFLTD1WRAFKOFT4TI0' # your Foursquare ID
ClIENT_SECRET = 'RCSNR5TH31NQRG2QYCHK101HRMTUZHBB2TSJ1CJU5UOGRXRQ' # your Foursquare Secret
VERSION = '20180604'
LIMIT =30
print('Your credentails:')
print('Foursquare_ID: ' + ClIENT_ID)
print('Foursquare_Secret:' + ClIENT_SECRET)
# Out:
# Your credentails:
# Foursquare_ID: 4FQQJE2LMGVLERRRE2BOFR1LQQR5ZEHFLTD1WRAFKOFT4TI0
# Foursquare_Secret:RCSNR5TH31NQRG2QYCHK101HRMTUZHBB2TSJ1CJU5UOGRXRQ

# %% [markdown]
# ## **Define the city and get its latitude & longitude**

# %%
# define the city and get its latitude & longitude 
city = 'Toronto'
geolocator = Nominatim(user_agent="foursquare_agent")
location = geolocator.geocode(city)
latitude = location.latitude
longitude = location.longitude
print(latitude, longitude)
# Out:
# 43.6534817 -79.3839347

# %% [markdown]
# ## **Search for Hotels**

# %%
# search for hotels
search_query = 'Hotel'
radius = 500

# Define the corresponding URL
url = 'https://api.foursquare.com/v2/venues/search?client_id={}&client_secret={}&ll={},{}&v={}&query={}&radius={}&limit={}'\
.format(ClIENT_ID, ClIENT_SECRET, latitude, longitude, VERSION, search_query, radius, LIMIT)
url
# Out:
# 'https://api.foursquare.com/v2/venues/search?client_id=4FQQJE2LMGVLERRRE2BOFR1LQQR5ZEHFLTD1WRAFKOFT4TI0&client_secret=RCSNR5TH31NQRG2QYCHK101HRMTUZHBB2TSJ1CJU5UOGRXRQ&ll=43.6534817,-79.3839347&v=20180604&query=Hotel&radius=500&limit=30'

# %%
# Send the GET Request and examine the results
results = requests.get(url).json()
#results

# %%
# assign relevant part of JSON to venues
venues = results['response']['venues']

# tranform venues into a dataframe
#dataframe = json_normalize(venues)
dataframe=pd.json_normalize(venues)
dataframe.head()
# Out:
#                          id                             name  \
# 0  4ab2d511f964a5209b6c20e3    Sheraton Centre Toronto Hotel
# 1  51d212c3498ebf27dc469bc9                    Chelsea Hotel
# 2  4af96fbbf964a520c01122e3  One King West Hotel & Residence
# 3  4ae61cf6f964a520caa421e3             Pantages Hotel & Spa
# 4  4b68aed1f964a520de862be3   The Rex Hotel Jazz & Blues Bar
#
#                                           categories    referralId  hasPerk  \
# 0  [{'id': '4bf58dd8d48988d1fa931735', 'name': 'H...  v-1587777906    False
# 1  [{'id': '4bf58dd8d48988d1fa931735', 'name': 'H...  v-1587777906    False
# 2  [{'id': '4bf58dd8d48988d1fa931735', 'name': 'H...  v-1587777906    False
# 3  [{'id': '4bf58dd8d48988d1fa931735', 'name': 'H...  v-1587777906    False
# 4  [{'id': '4bf58dd8d48988d1e7931735', 'name': 'J...  v-1587777906    False
#
#          location.address location.crossStreet  location.lat  location.lng  \
# 0   123 Queen Street West          at York St.     43.650594    -79.384530
# 1  33 Gerrard Street West          at Yonge St     43.658498    -79.383097
# 2             1 King St W         at Yonge St.     43.649139    -79.377876
# 3         200 Victoria St         at Shuter St     43.654498    -79.379035
# 4          194 Queen St W  Queen & St. Patrick     43.650505    -79.388577
#
#                              location.labeledLatLngs  location.distance  \
# 0  [{'label': 'display', 'lat': 43.6505944, 'lng'...                324
# 1  [{'label': 'display', 'lat': 43.65849759157591...                562
# 2  [{'label': 'display', 'lat': 43.6491395, 'lng'...                686
# 3  [{'label': 'display', 'lat': 43.65449797039222...                410
# 4  [{'label': 'display', 'lat': 43.65050475544005...                499
#
#   location.postalCode location.cc location.city location.state  \
# 0             M5H 2M9          CA       Toronto             ON
# 1             M5G 1Z4          CA       Toronto             ON
# 2             M5H 1A1          CA       Toronto             ON
# 3                 NaN          CA       Toronto             ON
# 4             M5V 1Z1          CA       Toronto             ON
#
#   location.country                          location.formattedAddress  \
# 0           Canada  [123 Queen Street West (at York St.), Toronto ...
# 1           Canada  [33 Gerrard Street West (at Yonge St), Toronto...
# 2           Canada  [1 King St W (at Yonge St.), Toronto ON M5H 1A...
# 3           Canada  [200 Victoria St (at Shuter St), Toronto ON, C...
# 4           Canada  [194 Queen St W (Queen & St. Patrick), Toronto...
#
#   venuePage.id location.neighborhood
# 0          NaN                   NaN
# 1          NaN                   NaN
# 2          NaN                   NaN
# 3          NaN                   NaN
# 4     62225795                   NaN

# %% [markdown]
# ## **Clean Hotel Dataframe**

# %%
# keep only columns that include venue name, and anything that is associated with location
clean_columns = ['name', 'categories'] + [col for col in dataframe.columns if col.startswith('location.')]+ ['id']
clean_dataframe = dataframe.loc[:,clean_columns]

# function that extracts the category of the venue
def get_category_type(row):
    try:
        categories_list = row['categories']
    except:
        categories_list = row['venue.categories']
        
    if len(categories_list) == 0:
        return None
    else:
        return categories_list[0]['name']

# filter the category for each row
clean_dataframe['categories'] = clean_dataframe.apply(get_category_type, axis=1)

# clean column names by keeping only last term
clean_dataframe.columns = [column.split('.')[-1] for column in clean_dataframe.columns]

clean_dataframe.head()
# Out:
#                               name categories                 address  \
# 0    Sheraton Centre Toronto Hotel      Hotel   123 Queen Street West
# 1                    Chelsea Hotel      Hotel  33 Gerrard Street West
# 2  One King West Hotel & Residence      Hotel             1 King St W
# 3             Pantages Hotel & Spa      Hotel         200 Victoria St
# 4   The Rex Hotel Jazz & Blues Bar  Jazz Club          194 Queen St W
#
#            crossStreet        lat        lng  \
# 0          at York St.  43.650594 -79.384530
# 1          at Yonge St  43.658498 -79.383097
# 2         at Yonge St.  43.649139 -79.377876
# 3         at Shuter St  43.654498 -79.379035
# 4  Queen & St. Patrick  43.650505 -79.388577
#
#                                       labeledLatLngs  distance postalCode  cc  \
# 0  [{'label': 'display', 'lat': 43.6505944, 'lng'...       324    M5H 2M9  CA
# 1  [{'label': 'display', 'lat': 43.65849759157591...       562    M5G 1Z4  CA
# 2  [{'label': 'display', 'lat': 43.6491395, 'lng'...       686    M5H 1A1  CA
# 3  [{'label': 'display', 'lat': 43.65449797039222...       410        NaN  CA
# 4  [{'label': 'display', 'lat': 43.65050475544005...       499    M5V 1Z1  CA
#
#       city state country                                   formattedAddress  \
# 0  Toronto    ON  Canada  [123 Queen Street West (at York St.), Toronto ...
# 1  Toronto    ON  Canada  [33 Gerrard Street West (at Yonge St), Toronto...
# 2  Toronto    ON  Canada  [1 King St W (at Yonge St.), Toronto ON M5H 1A...
# 3  Toronto    ON  Canada  [200 Victoria St (at Shuter St), Toronto ON, C...
# 4  Toronto    ON  Canada  [194 Queen St W (Queen & St. Patrick), Toronto...
#
#   neighborhood                        id
# 0          NaN  4ab2d511f964a5209b6c20e3
# 1          NaN  51d212c3498ebf27dc469bc9
# 2          NaN  4af96fbbf964a520c01122e3
# 3          NaN  4ae61cf6f964a520caa421e3
# 4          NaN  4b68aed1f964a520de862be3

# %%
# delete unnecessary columns
clean_dataframe2= clean_dataframe.drop(['cc', 'city', 'country', 'crossStreet', 'distance', 'formattedAddress',\
                                        'labeledLatLngs','neighborhood', 'id'], axis=1)
clean_dataframe2
# Out:
#                                               name  \
# 0                    Sheraton Centre Toronto Hotel
# 1                                    Chelsea Hotel
# 2                  One King West Hotel & Residence
# 3                             Pantages Hotel & Spa
# 4                   The Rex Hotel Jazz & Blues Bar
# 5                    Crew Room Eaton Chelsea Hotel
# 6                                   VFM Test Hotel
# 7          Cosmopolitan Toronto Centre Hotel & Spa
# 8                Sheraton Centre Hotel Club Lounge
# 9                                  Stathcona Hotel
# 10  Sheraton Centre Toronto Hotel - Grand Ballroom
# 11                                  Pentagos hotel
# 12                Shizen Spa at the Pantages Hotel
# 13                              Pantages Hotel Gym
# 14                                       650 Hotel
# 15                   Pantages Hotel Toronto Centre
# 16                               Be SixFifty Hotel
# 17              Henri's Bar at One King West hotel
# 18                   The Spa At The Adelaide Hotel
# 19         Smoldering remains of the Empress Hotel
# 20                    Bond Place Hotel Parking Lot
# 21  Chelsea Hotel, Toronto Meetings & Events Venue
# 22                                  St Regis Hotel
# 23           Suites at One King West Hotel Toronto
# 24                      The Adelaide Hotel Toronto
# 25                           89 Chestnut Residence
# 26                            DoubleTree by Hilton
# 27                                  Fitness Centre
# 28                                  Grand Ballroom
# 29    Marriott Downtown at CF Toronto Eaton Centre
#
#                                   categories                        address  \
# 0                                      Hotel          123 Queen Street West
# 1                                      Hotel         33 Gerrard Street West
# 2                                      Hotel                    1 King St W
# 3                                      Hotel                200 Victoria St
# 4                                  Jazz Club                 194 Queen St W
# 5                                      Hotel         33 Gerrard Street West
# 6                                      Hotel                 123 Test Drive
# 7                                      Hotel                  8 Colborne St
# 8                                     Lounge                            NaN
# 9                                      Hotel                            NaN
# 10                                  Ballroom          123 Queen Street West
# 11  Residential Building (Apartment / Condo)                            NaN
# 12                                       Spa                200 Victoria St
# 13                                       Gym               200 Victoria St.
# 14                                     Hotel                 650 Bay Street
# 15  Residential Building (Apartment / Condo)            200 Victoria Street
# 16                                     Hotel                 650 Bay Street
# 17                       American Restaurant                    1 King West
# 18                                       Spa                     325 Bay St
# 19                                     Hotel                   335 Yonge St
# 20                        Miscellaneous Shop                Bond And Dundas
# 21                         Convention Center         33 Gerrard Street West
# 22                                     Hotel                     325 Bay St
# 23                                     Hotel  1 King St W Toronto ON Canada
# 24                                     Hotel                     325 Bay St
# 25                    College Residence Hall                89 Chestnut St.
# 26                                     Hotel            108 Chestnut Street
# 27                                       Gym                    525 Bay St.
# 28                               Event Space                123 Queen St. W
# 29                                     Hotel                 525 Bay Street
#
#           lat        lng postalCode state
# 0   43.650594 -79.384530    M5H 2M9    ON
# 1   43.658498 -79.383097    M5G 1Z4    ON
# 2   43.649139 -79.377876    M5H 1A1    ON
# 3   43.654498 -79.379035        NaN    ON
# 4   43.650505 -79.388577    M5V 1Z1    ON
# 5   43.658094 -79.382711        NaN    ON
# 6   43.658434 -79.387894    M2M 2M2    ON
# 7   43.649064 -79.377598    M5E 1E1    ON
# 8   43.651063 -79.384527    M5H 2M9    ON
# 9   43.654947 -79.386359        NaN    ON
# 10  43.651200 -79.384520        NaN    ON
# 11  43.653976 -79.379875        NaN    ON
# 12  43.655198 -79.379913        NaN    ON
# 13  43.654464 -79.379036    M5B 1V8    ON
# 14  43.657046 -79.384411        NaN    ON
# 15  43.655205 -79.379182    M5B 1V8    ON
# 16  43.657120 -79.384560        NaN    ON
# 17  43.648945 -79.378028        NaN    ON
# 18  43.649725 -79.380346    M5H 4G5    ON
# 19  43.657956 -79.381698        NaN    ON
# 20  43.656224 -79.378830        NaN   NaN
# 21  43.658446 -79.382985    M5G 1Z4    ON
# 22  43.649770 -79.380701    M5H 4G3    ON
# 23  43.649077 -79.378468        NaN    ON
# 24  43.649831 -79.380164    M5H 4G3    ON
# 25  43.654160 -79.385291    M5G 1R1    ON
# 26  43.654608 -79.385942    M5G 1R3    ON
# 27  43.654690 -79.381739    M5G 2L2    ON
# 28  43.651217 -79.383771    M5H 2M9    ON
# 29  43.654728 -79.382422    M5G 2L2    ON

# %%
# delete rows with none values
clean_dataframe3 = clean_dataframe2.dropna(axis=0, how='any', thresh=None, subset=None, inplace=False)
clean_dataframe3
# Out:
#                                               name  \
# 0                    Sheraton Centre Toronto Hotel
# 1                                    Chelsea Hotel
# 2                  One King West Hotel & Residence
# 4                   The Rex Hotel Jazz & Blues Bar
# 6                                   VFM Test Hotel
# 7          Cosmopolitan Toronto Centre Hotel & Spa
# 13                              Pantages Hotel Gym
# 15                   Pantages Hotel Toronto Centre
# 18                   The Spa At The Adelaide Hotel
# 21  Chelsea Hotel, Toronto Meetings & Events Venue
# 22                                  St Regis Hotel
# 24                      The Adelaide Hotel Toronto
# 25                           89 Chestnut Residence
# 26                            DoubleTree by Hilton
# 27                                  Fitness Centre
# 28                                  Grand Ballroom
# 29    Marriott Downtown at CF Toronto Eaton Centre
#
#                                   categories                 address  \
# 0                                      Hotel   123 Queen Street West
# 1                                      Hotel  33 Gerrard Street West
# 2                                      Hotel             1 King St W
# 4                                  Jazz Club          194 Queen St W
# 6                                      Hotel          123 Test Drive
# 7                                      Hotel           8 Colborne St
# 13                                       Gym        200 Victoria St.
# 15  Residential Building (Apartment / Condo)     200 Victoria Street
# 18                                       Spa              325 Bay St
# 21                         Convention Center  33 Gerrard Street West
# 22                                     Hotel              325 Bay St
# 24                                     Hotel              325 Bay St
# 25                    College Residence Hall         89 Chestnut St.
# 26                                     Hotel     108 Chestnut Street
# 27                                       Gym             525 Bay St.
# 28                               Event Space         123 Queen St. W
# 29                                     Hotel          525 Bay Street
#
#           lat        lng postalCode state
# 0   43.650594 -79.384530    M5H 2M9    ON
# 1   43.658498 -79.383097    M5G 1Z4    ON
# 2   43.649139 -79.377876    M5H 1A1    ON
# 4   43.650505 -79.388577    M5V 1Z1    ON
# 6   43.658434 -79.387894    M2M 2M2    ON
# 7   43.649064 -79.377598    M5E 1E1    ON
# 13  43.654464 -79.379036    M5B 1V8    ON
# 15  43.655205 -79.379182    M5B 1V8    ON
# 18  43.649725 -79.380346    M5H 4G5    ON
# 21  43.658446 -79.382985    M5G 1Z4    ON
# 22  43.649770 -79.380701    M5H 4G3    ON
# 24  43.649831 -79.380164    M5H 4G3    ON
# 25  43.654160 -79.385291    M5G 1R1    ON
# 26  43.654608 -79.385942    M5G 1R3    ON
# 27  43.654690 -79.381739    M5G 2L2    ON
# 28  43.651217 -79.383771    M5H 2M9    ON
# 29  43.654728 -79.382422    M5G 2L2    ON

# %%
# delete rows which its category is not Hotel or Event Space
array= ['Hotel', 'Event Space']
hotel_dataframe= clean_dataframe3.loc[clean_dataframe3['categories'].isin(array)]
hotel_dataframe
# Out:
#                                             name   categories  \
# 0                  Sheraton Centre Toronto Hotel        Hotel
# 1                                  Chelsea Hotel        Hotel
# 2                One King West Hotel & Residence        Hotel
# 6                                 VFM Test Hotel        Hotel
# 7        Cosmopolitan Toronto Centre Hotel & Spa        Hotel
# 22                                St Regis Hotel        Hotel
# 24                    The Adelaide Hotel Toronto        Hotel
# 26                          DoubleTree by Hilton        Hotel
# 28                                Grand Ballroom  Event Space
# 29  Marriott Downtown at CF Toronto Eaton Centre        Hotel
#
#                    address        lat        lng postalCode state
# 0    123 Queen Street West  43.650594 -79.384530    M5H 2M9    ON
# 1   33 Gerrard Street West  43.658498 -79.383097    M5G 1Z4    ON
# 2              1 King St W  43.649139 -79.377876    M5H 1A1    ON
# 6           123 Test Drive  43.658434 -79.387894    M2M 2M2    ON
# 7            8 Colborne St  43.649064 -79.377598    M5E 1E1    ON
# 22              325 Bay St  43.649770 -79.380701    M5H 4G3    ON
# 24              325 Bay St  43.649831 -79.380164    M5H 4G3    ON
# 26     108 Chestnut Street  43.654608 -79.385942    M5G 1R3    ON
# 28         123 Queen St. W  43.651217 -79.383771    M5H 2M9    ON
# 29          525 Bay Street  43.654728 -79.382422    M5G 2L2    ON

# %%
# delete rows which has duplicate hotel's name
df_hotels = hotel_dataframe.drop_duplicates(subset='name', keep="first")
df_hotels
# Out:
#                                             name   categories  \
# 0                  Sheraton Centre Toronto Hotel        Hotel
# 1                                  Chelsea Hotel        Hotel
# 2                One King West Hotel & Residence        Hotel
# 6                                 VFM Test Hotel        Hotel
# 7        Cosmopolitan Toronto Centre Hotel & Spa        Hotel
# 22                                St Regis Hotel        Hotel
# 24                    The Adelaide Hotel Toronto        Hotel
# 26                          DoubleTree by Hilton        Hotel
# 28                                Grand Ballroom  Event Space
# 29  Marriott Downtown at CF Toronto Eaton Centre        Hotel
#
#                    address        lat        lng postalCode state
# 0    123 Queen Street West  43.650594 -79.384530    M5H 2M9    ON
# 1   33 Gerrard Street West  43.658498 -79.383097    M5G 1Z4    ON
# 2              1 King St W  43.649139 -79.377876    M5H 1A1    ON
# 6           123 Test Drive  43.658434 -79.387894    M2M 2M2    ON
# 7            8 Colborne St  43.649064 -79.377598    M5E 1E1    ON
# 22              325 Bay St  43.649770 -79.380701    M5H 4G3    ON
# 24              325 Bay St  43.649831 -79.380164    M5H 4G3    ON
# 26     108 Chestnut Street  43.654608 -79.385942    M5G 1R3    ON
# 28         123 Queen St. W  43.651217 -79.383771    M5H 2M9    ON
# 29          525 Bay Street  43.654728 -79.382422    M5G 2L2    ON

# %%
# choose the hotel which has the same postalCode with the event space
df_hotel = df_hotels[df_hotels.postalCode == 'M5H 2M9']
df_hotel
# Out:
#                              name   categories                address  \
# 0   Sheraton Centre Toronto Hotel        Hotel  123 Queen Street West
# 28                 Grand Ballroom  Event Space        123 Queen St. W
#
#           lat        lng postalCode state
# 0   43.650594 -79.384530    M5H 2M9    ON
# 28  43.651217 -79.383771    M5H 2M9    ON

# %% [markdown]
# ## **Search for Parks**

# %%
# search for Parks
search_query = 'Park'
radius = 10000

# Define the corresponding URL
url = 'https://api.foursquare.com/v2/venues/search?client_id={}&client_secret={}&ll={},{}&v={}&query={}&radius={}&limit={}'\
.format(ClIENT_ID, ClIENT_SECRET, latitude, longitude, VERSION, search_query, radius, LIMIT)
url
# Out:
# 'https://api.foursquare.com/v2/venues/search?client_id=4FQQJE2LMGVLERRRE2BOFR1LQQR5ZEHFLTD1WRAFKOFT4TI0&client_secret=RCSNR5TH31NQRG2QYCHK101HRMTUZHBB2TSJ1CJU5UOGRXRQ&ll=43.6534817,-79.3839347&v=20180604&query=Park&radius=10000&limit=30'

# %%
# Send the GET Request and examine the results
presults = requests.get(url).json()
#presults

# %%
# assign relevant part of JSON to venues
venues = presults['response']['venues']

# tranform venues into a dataframe
park_dataframe = pd.json_normalize(venues)
park_dataframe.head()
# Out:
#                          id                                name  \
# 0  4b170e47f964a5208cc123e3         Queen's Park Subway Station
# 1  4b54deadf964a520a3d027e3                         Grange Park
# 2  4b9177e4f964a520d2be33e3  TTC Streetcar #403 - Victoria park
# 3  4d3a1d23325ff04db2dd1845    Residences at College Park North
# 4  4bfc5019da7120a132df49fd   St. Andrews Playground / Dog Park
#
#                                           categories    referralId  hasPerk  \
# 0  [{'id': '4bf58dd8d48988d1fd931735', 'name': 'M...  v-1587778142    False
# 1  [{'id': '4bf58dd8d48988d163941735', 'name': 'P...  v-1587778142    False
# 2  [{'id': '4bf58dd8d48988d1fc931735', 'name': 'L...  v-1587778142    False
# 3  [{'id': '4d954b06a243a5684965b473', 'name': 'R...  v-1587778142    False
# 4  [{'id': '4bf58dd8d48988d163941735', 'name': 'P...  v-1587778142    False
#
#            location.address               location.crossStreet  location.lat  \
# 0        691 University Ave                      at College St     43.660006
# 1                       NaN                                NaN     43.652488
# 2                       NaN                                NaN     43.650735
# 3               763 Bay St.  btwn. College St. and Gerrard St.     43.659822
# 4  450 Adelaide Street West           Brant St & Adelaide St W     43.647388
#
#    location.lng                            location.labeledLatLngs  \
# 0    -79.390272  [{'label': 'display', 'lat': 43.66000635700919...
# 1    -79.392053  [{'label': 'display', 'lat': 43.65248755299856...
# 2    -79.386921  [{'label': 'display', 'lat': 43.650735, 'lng':...
# 3    -79.385159  [{'label': 'display', 'lat': 43.65982157793473...
# 4    -79.398752  [{'label': 'display', 'lat': 43.64738759338116...
#
#    location.distance location.postalCode location.cc location.city  \
# 0                887             M5G 2P1          CA       Toronto
# 1                663                 NaN          CA       Toronto
# 2                389                 NaN          CA       Toronto
# 3                712             M5G 2R3          CA       Toronto
# 4               1372                 NaN          CA       Toronto
#
#   location.state location.country  \
# 0             ON           Canada
# 1             ON           Canada
# 2             ON           Canada
# 3             ON           Canada
# 4             ON           Canada
#
#                            location.formattedAddress venuePage.id
# 0  [691 University Ave (at College St), Toronto O...          NaN
# 1  [btwn College, University, Queen & Spadina, To...          NaN
# 2                               [Toronto ON, Canada]          NaN
# 3  [763 Bay St. (btwn. College St. and Gerrard St...          NaN
# 4  [450 Adelaide Street West (Brant St & Adelaide...          NaN

# %% [markdown]
# ## **Clean Park Dataframe**

# %%
# keep only columns that include venue name, and anything that is associated with location
park_clean_columns = ['name', 'categories'] + [col for col in park_dataframe.columns if col.startswith('location.')]+ ['id']
clean_park_dataframe = park_dataframe.loc[:,park_clean_columns]

# function that extracts the category of the venue
def get_category_type(row):
    try:
        categories_list1 = row['categories']
    except:
        categories_list1 = row['venue.categories']
        
    if len(categories_list1) == 0:
        return None
    else:
        return categories_list1[0]['name']

# filter the category for each row
clean_park_dataframe['categories'] = clean_park_dataframe.apply(get_category_type, axis=1)

# clean column names by keeping only last term
clean_park_dataframe.columns = [column.split('.')[-1] for column in clean_park_dataframe.columns]

clean_park_dataframe.head()
# Out:
#                                  name  \
# 0         Queen's Park Subway Station
# 1                         Grange Park
# 2  TTC Streetcar #403 - Victoria park
# 3    Residences at College Park North
# 4   St. Andrews Playground / Dog Park
#
#                                  categories                   address  \
# 0                             Metro Station        691 University Ave
# 1                                      Park                       NaN
# 2                        Light Rail Station                       NaN
# 3  Residential Building (Apartment / Condo)               763 Bay St.
# 4                                      Park  450 Adelaide Street West
#
#                          crossStreet        lat        lng  \
# 0                      at College St  43.660006 -79.390272
# 1                                NaN  43.652488 -79.392053
# 2                                NaN  43.650735 -79.386921
# 3  btwn. College St. and Gerrard St.  43.659822 -79.385159
# 4           Brant St & Adelaide St W  43.647388 -79.398752
#
#                                       labeledLatLngs  distance postalCode  cc  \
# 0  [{'label': 'display', 'lat': 43.66000635700919...       887    M5G 2P1  CA
# 1  [{'label': 'display', 'lat': 43.65248755299856...       663        NaN  CA
# 2  [{'label': 'display', 'lat': 43.650735, 'lng':...       389        NaN  CA
# 3  [{'label': 'display', 'lat': 43.65982157793473...       712    M5G 2R3  CA
# 4  [{'label': 'display', 'lat': 43.64738759338116...      1372        NaN  CA
#
#       city state country                                   formattedAddress  \
# 0  Toronto    ON  Canada  [691 University Ave (at College St), Toronto O...
# 1  Toronto    ON  Canada  [btwn College, University, Queen & Spadina, To...
# 2  Toronto    ON  Canada                               [Toronto ON, Canada]
# 3  Toronto    ON  Canada  [763 Bay St. (btwn. College St. and Gerrard St...
# 4  Toronto    ON  Canada  [450 Adelaide Street West (Brant St & Adelaide...
#
#                          id
# 0  4b170e47f964a5208cc123e3
# 1  4b54deadf964a520a3d027e3
# 2  4b9177e4f964a520d2be33e3
# 3  4d3a1d23325ff04db2dd1845
# 4  4bfc5019da7120a132df49fd

# %%
# delete unnecessary columns
clean_park_dataframe2= clean_park_dataframe.drop(['cc', 'city', 'country', 'crossStreet', 'distance', 'formattedAddress',\
                                        'labeledLatLngs', 'id'], axis=1)
clean_park_dataframe2
# Out:
#                                    name  \
# 0           Queen's Park Subway Station
# 1                           Grange Park
# 2    TTC Streetcar #403 - Victoria park
# 3      Residences at College Park North
# 4     St. Andrews Playground / Dog Park
# 5                           Berczy Park
# 6                Physiomed College Park
# 7                         One Park Lane
# 8         Crunch Fitness - College Park
# 9      Toothworks - College Park Dental
# 10              St Lawrence on the Park
# 11                         Queen's Park
# 12                 Clarence Square Park
# 13              Moss Park Tennis Courts
# 14                  Tommy Thompson Park
# 15                             HTO Park
# 16                  Riverdale Park West
# 17                          Regent Park
# 18         Regent Park Community Centre
# 19               Trinity Bellwoods Park
# 20                  Riverdale Park East
# 21                    Barbara Hall Park
# 22                    Barbara Hall Park
# 23              Park Hyatt Bridal Suite
# 24                 Bellevue Square Park
# 25                         Wilfrid Park
# 26  Regent Park Community Health Centre
# 27               Parliament Square Park
# 28                    Larry Sefton Park
# 29              Cawthra Square Dog Park
#
#                                   categories                       address  \
# 0                              Metro Station            691 University Ave
# 1                                       Park                           NaN
# 2                         Light Rail Station                           NaN
# 3   Residential Building (Apartment / Condo)                   763 Bay St.
# 4                                       Park      450 Adelaide Street West
# 5                                       Park        35 Wellington St. East
# 6                             Medical Center                  382 Yonge St
# 7   Residential Building (Apartment / Condo)                 280 Simcoe St
# 8                       Gym / Fitness Center              382 Yonge Street
# 9                           Dentist's Office        444 Yonge St, Unit M16
# 10                                  Building               65 Scadding Ave
# 11                                      Park               University Ave.
# 12                                      Park                   Spadina Ave
# 13                              Tennis Court                     Moss Park
# 14                                      Park                     Leslie St
# 15                                      Park                  Queen's Quay
# 16                                      Park               500 Gerrard St.
# 17                              Neighborhood                           NaN
# 18                          Community Center               465 Dundas St E
# 19                                      Park            1053 Dundas St. W.
# 20                                      Park             550 Broadview Ave
# 21                                      Park             519 Church Street
# 22                                      Park                 519 Church St
# 23                                     Hotel                   4 Avenue Rd
# 24                                      Park  btwn Bellevue & Augusta Ave.
# 25                                    Office                           NaN
# 26                          Community Center               465 Dundas St E
# 27                                      Park          44 Parliament Street
# 28                                     Plaza                           NaN
# 29                                   Dog Run                519 Church St.
#
#           lat        lng postalCode state
# 0   43.660006 -79.390272    M5G 2P1    ON
# 1   43.652488 -79.392053        NaN    ON
# 2   43.650735 -79.386921        NaN    ON
# 3   43.659822 -79.385159    M5G 2R3    ON
# 4   43.647388 -79.398752        NaN    ON
# 5   43.648048 -79.375172        NaN    ON
# 6   43.659240 -79.382860    M5B 1S8    ON
# 7   43.655442 -79.390056    M5T 2Y5    ON
# 8   43.659263 -79.382632    M5G 1S8    ON
# 9   43.660009 -79.383905        NaN    ON
# 10  43.648963 -79.364868        NaN    ON
# 11  43.663946 -79.392180    M5R 2E8    ON
# 12  43.644222 -79.394230        NaN    ON
# 13  43.655337 -79.371923        NaN    ON
# 14  43.634180 -79.323671        NaN    ON
# 15  43.637949 -79.387820        NaN    ON
# 16  43.666048 -79.360941    M5A 2H3    ON
# 17  43.660009 -79.364191        NaN    ON
# 18  43.659512 -79.363048    M5A 2B2    ON
# 19  43.647072 -79.413756    M5H 2N2    ON
# 20  43.669951 -79.355493    M4K 2P1    ON
# 21  43.666728 -79.381084        NaN    ON
# 22  43.666879 -79.381068    M4Y 2K9    ON
# 23  43.668849 -79.394460        NaN    ON
# 24  43.653610 -79.402199    M5T 2N4    ON
# 25  43.650999 -79.364915        NaN   NaN
# 26  43.659572 -79.365759        NaN    ON
# 27  43.650264 -79.362195        NaN    ON
# 28  43.654589 -79.383405        NaN   NaN
# 29  43.666583 -79.380040        NaN    ON

# %%
# delete rows with none values
clean_park_dataframe3 = clean_park_dataframe2.dropna(axis=0, how='any', thresh=None, subset=None, inplace=False)
clean_park_dataframe3
# Out:
#                                 name  \
# 0        Queen's Park Subway Station
# 3   Residences at College Park North
# 6             Physiomed College Park
# 7                      One Park Lane
# 8      Crunch Fitness - College Park
# 11                      Queen's Park
# 16               Riverdale Park West
# 18      Regent Park Community Centre
# 19            Trinity Bellwoods Park
# 20               Riverdale Park East
# 22                 Barbara Hall Park
# 24              Bellevue Square Park
#
#                                   categories                       address  \
# 0                              Metro Station            691 University Ave
# 3   Residential Building (Apartment / Condo)                   763 Bay St.
# 6                             Medical Center                  382 Yonge St
# 7   Residential Building (Apartment / Condo)                 280 Simcoe St
# 8                       Gym / Fitness Center              382 Yonge Street
# 11                                      Park               University Ave.
# 16                                      Park               500 Gerrard St.
# 18                          Community Center               465 Dundas St E
# 19                                      Park            1053 Dundas St. W.
# 20                                      Park             550 Broadview Ave
# 22                                      Park                 519 Church St
# 24                                      Park  btwn Bellevue & Augusta Ave.
#
#           lat        lng postalCode state
# 0   43.660006 -79.390272    M5G 2P1    ON
# 3   43.659822 -79.385159    M5G 2R3    ON
# 6   43.659240 -79.382860    M5B 1S8    ON
# 7   43.655442 -79.390056    M5T 2Y5    ON
# 8   43.659263 -79.382632    M5G 1S8    ON
# 11  43.663946 -79.392180    M5R 2E8    ON
# 16  43.666048 -79.360941    M5A 2H3    ON
# 18  43.659512 -79.363048    M5A 2B2    ON
# 19  43.647072 -79.413756    M5H 2N2    ON
# 20  43.669951 -79.355493    M4K 2P1    ON
# 22  43.666879 -79.381068    M4Y 2K9    ON
# 24  43.653610 -79.402199    M5T 2N4    ON

# %%
# delete rows which its category is not Park
df_park = clean_park_dataframe3[clean_park_dataframe3.categories == 'Park']
df_park
# Out:
#                       name categories                       address  \
# 11            Queen's Park       Park               University Ave.
# 16     Riverdale Park West       Park               500 Gerrard St.
# 19  Trinity Bellwoods Park       Park            1053 Dundas St. W.
# 20     Riverdale Park East       Park             550 Broadview Ave
# 22       Barbara Hall Park       Park                 519 Church St
# 24    Bellevue Square Park       Park  btwn Bellevue & Augusta Ave.
#
#           lat        lng postalCode state
# 11  43.663946 -79.392180    M5R 2E8    ON
# 16  43.666048 -79.360941    M5A 2H3    ON
# 19  43.647072 -79.413756    M5H 2N2    ON
# 20  43.669951 -79.355493    M4K 2P1    ON
# 22  43.666879 -79.381068    M4Y 2K9    ON
# 24  43.653610 -79.402199    M5T 2N4    ON

# %% [markdown]
# ## **Search for Restaurants**

# %%
# search for Restaurants
search_query = 'Restaurant'
radius = 10000

# Define the corresponding URL
url = 'https://api.foursquare.com/v2/venues/search?client_id={}&client_secret={}&ll={},{}&v={}&query={}&radius={}&limit={}'.format(ClIENT_ID, ClIENT_SECRET, latitude, longitude, VERSION, search_query, radius, LIMIT)
url
# Out:
# 'https://api.foursquare.com/v2/venues/search?client_id=4FQQJE2LMGVLERRRE2BOFR1LQQR5ZEHFLTD1WRAFKOFT4TI0&client_secret=RCSNR5TH31NQRG2QYCHK101HRMTUZHBB2TSJ1CJU5UOGRXRQ&ll=43.6534817,-79.3839347&v=20180604&query=Restaurant&radius=10000&limit=30'

# %%
# Send the GET Request and examine the results
Rresults = requests.get(url).json()
#Rresults

# %%
# assign relevant part of JSON to venues
venues = Rresults['response']['venues']

# tranform venues into a dataframe
Restaurant_dataframe = pd.json_normalize(venues)
Restaurant_dataframe.head()
# Out:
#                          id                             name  \
# 0  4ad4c05ff964a52048f720e3  Hemispheres Restaurant & Bistro
# 1  4aef8854f964a5201cd921e3     Aroma Fine Indian Restaurant
# 2  4ada5d5bf964a520e92121e3   The Hot House Restaurant & Bar
# 3  4ad4c05cf964a52006f620e3            Victoria's Restaurant
# 4  4b074bb1f964a52077fb22e3         New Sky Restaurant 小沙田食家
#
#                                           categories    referralId  hasPerk  \
# 0  [{'id': '4bf58dd8d48988d14e941735', 'name': 'A...  v-1587778227    False
# 1  [{'id': '4bf58dd8d48988d10f941735', 'name': 'I...  v-1587778227    False
# 2  [{'id': '4bf58dd8d48988d14e941735', 'name': 'A...  v-1587778227    False
# 3  [{'id': '4bf58dd8d48988d1c4941735', 'name': 'R...  v-1587778227    False
# 4  [{'id': '4bf58dd8d48988d145941735', 'name': 'C...  v-1587778227    False
#
#       location.address  location.lat  location.lng  \
# 0  110 Chestnut Street     43.654884    -79.385931
# 1       287 King St. W     43.646463    -79.389644
# 2         35 Church St     43.648824    -79.373702
# 3  37 King Street East     43.649298    -79.376431
# 4     353 Spadina Ave.     43.655337    -79.398897
#
#                              location.labeledLatLngs  location.distance  \
# 0  [{'label': 'display', 'lat': 43.65488413420439...                224
# 1  [{'label': 'display', 'lat': 43.64646252150344...                906
# 2  [{'label': 'display', 'lat': 43.64882370529773...                973
# 3  [{'label': 'display', 'lat': 43.64929834396347...                763
# 4  [{'label': 'display', 'lat': 43.65533674412141...               1222
#
#   location.postalCode location.cc location.city location.state  \
# 0             M5G 1R3          CA       Toronto             ON
# 1             M5V 1J5          CA       Toronto             ON
# 2             M5E 1T3          CA       Toronto             ON
# 3             M5C 1E9          CA       Toronto             ON
# 4             M5T 2G3          CA       Toronto             ON
#
#   location.country                          location.formattedAddress  \
# 0           Canada  [110 Chestnut Street, Toronto ON M5G 1R3, Canada]
# 1           Canada  [287 King St. W (at John St.), Toronto ON M5V ...
# 2           Canada  [35 Church St (at Front St E), Toronto ON M5E ...
# 3           Canada  [37 King Street East (at Le Meridien King Edwa...
# 4           Canada     [353 Spadina Ave., Toronto ON M5T 2G3, Canada]
#
#                location.crossStreet venuePage.id location.neighborhood
# 0                               NaN          NaN                   NaN
# 1                       at John St.          NaN                   NaN
# 2                     at Front St E          NaN                   NaN
# 3  at Le Meridien King Edward Hotel    498556908                   NaN
# 4                               NaN          NaN                   NaN

# %% [markdown]
# ## **Clean Restaurant Dataframe**

# %%
# keep only columns that include venue name, and anything that is associated with location
Restaurant_clean_columns = ['name', 'categories'] + [col for col in Restaurant_dataframe.columns if col.startswith('location.')]+ ['id']
clean_Restaurant_dataframe = Restaurant_dataframe.loc[:,Restaurant_clean_columns]

# function that extracts the category of the venue
def get_category_type(row):
    try:
        categories_list3 = row['categories']
    except:
        categories_list3 = row['venue.categories']
        
    if len(categories_list3) == 0:
        return None
    else:
        return categories_list3[0]['name']

# filter the category for each row
clean_Restaurant_dataframe['categories'] = clean_Restaurant_dataframe.apply(get_category_type, axis=1)

# clean column names by keeping only last term
clean_Restaurant_dataframe.columns = [column.split('.')[-1] for column in clean_Restaurant_dataframe.columns]

clean_Restaurant_dataframe.head()
# Out:
#                               name           categories              address  \
# 0  Hemispheres Restaurant & Bistro  American Restaurant  110 Chestnut Street
# 1     Aroma Fine Indian Restaurant    Indian Restaurant       287 King St. W
# 2   The Hot House Restaurant & Bar  American Restaurant         35 Church St
# 3            Victoria's Restaurant           Restaurant  37 King Street East
# 4         New Sky Restaurant 小沙田食家   Chinese Restaurant     353 Spadina Ave.
#
#          lat        lng                                     labeledLatLngs  \
# 0  43.654884 -79.385931  [{'label': 'display', 'lat': 43.65488413420439...
# 1  43.646463 -79.389644  [{'label': 'display', 'lat': 43.64646252150344...
# 2  43.648824 -79.373702  [{'label': 'display', 'lat': 43.64882370529773...
# 3  43.649298 -79.376431  [{'label': 'display', 'lat': 43.64929834396347...
# 4  43.655337 -79.398897  [{'label': 'display', 'lat': 43.65533674412141...
#
#    distance postalCode  cc     city state country  \
# 0       224    M5G 1R3  CA  Toronto    ON  Canada
# 1       906    M5V 1J5  CA  Toronto    ON  Canada
# 2       973    M5E 1T3  CA  Toronto    ON  Canada
# 3       763    M5C 1E9  CA  Toronto    ON  Canada
# 4      1222    M5T 2G3  CA  Toronto    ON  Canada
#
#                                     formattedAddress  \
# 0  [110 Chestnut Street, Toronto ON M5G 1R3, Canada]
# 1  [287 King St. W (at John St.), Toronto ON M5V ...
# 2  [35 Church St (at Front St E), Toronto ON M5E ...
# 3  [37 King Street East (at Le Meridien King Edwa...
# 4     [353 Spadina Ave., Toronto ON M5T 2G3, Canada]
#
#                         crossStreet neighborhood                        id
# 0                               NaN          NaN  4ad4c05ff964a52048f720e3
# 1                       at John St.          NaN  4aef8854f964a5201cd921e3
# 2                     at Front St E          NaN  4ada5d5bf964a520e92121e3
# 3  at Le Meridien King Edward Hotel          NaN  4ad4c05cf964a52006f620e3
# 4                               NaN          NaN  4b074bb1f964a52077fb22e3

# %%
# delete unnecessary columns
clean_Restaurant_dataframe2= clean_Restaurant_dataframe.drop(['cc', 'city', 'country', 'crossStreet', 'distance', 'formattedAddress',\
                                        'labeledLatLngs', 'neighborhood', 'id'], axis=1)
clean_Restaurant_dataframe2
# Out:
#                                               name               categories  \
# 0                  Hemispheres Restaurant & Bistro      American Restaurant
# 1                     Aroma Fine Indian Restaurant        Indian Restaurant
# 2                   The Hot House Restaurant & Bar      American Restaurant
# 3                            Victoria's Restaurant               Restaurant
# 4                         New Sky Restaurant 小沙田食家       Chinese Restaurant
# 5               Some Time BBQ Grill Restaurant 碳烤屋      Szechuan Restaurant
# 6               North-East Chinese Restaurant 華北美食       Chinese Restaurant
# 7                          Victor Restaurant & Bar                      Bar
# 8               Sky Dragon Chinese Restaurant 龍翔酒樓       Dim Sum Restaurant
# 9                                Studio Restaurant           Breakfast Spot
# 10                          Azure Restaurant & Bar               Restaurant
# 11                   Green Tea Restaurant Downtown       Chinese Restaurant
# 12                  Goldstone Noodle Restaurant 金石             Noodle House
# 13                         Swatow Restaurant 汕頭小食家       Chinese Restaurant
# 14                        Ka Chi Korean Restaurant        Korean Restaurant
# 15                                  360 Restaurant                 Wine Bar
# 16                          Rol San Restaurant 龍笙棧       Dim Sum Restaurant
# 17                     Cottage Restaurant & Lounge          Thai Restaurant
# 18         Tasty's Caribbean Restaurant & Catering     Caribbean Restaurant
# 19                               Arriba Restaurant               Restaurant
# 20               Kensington Cornerstone Restaurant           Breakfast Spot
# 21                           Sightlines Restaurant      American Restaurant
# 22                           Restaurant | Adelaide               Restaurant
# 23                   Micheal's Restaurant and Deli                      Bar
# 24                      Alio Restaurant & Wine Bar       Italian Restaurant
# 25                    Yueh Tung Chinese Restaurant       Chinese Restaurant
# 26               El Rancho Restaurant & Night Club                Nightclub
# 27  Sassafraz | Cafe | Restaurant | Private Events              Event Space
# 28                 Kyoto House Japanese Restaurant         Sushi Restaurant
# 29                     Woodlot Restaurant & Bakery  New American Restaurant
#
#                             address        lat        lng postalCode state
# 0               110 Chestnut Street  43.654884 -79.385931    M5G 1R3    ON
# 1                    287 King St. W  43.646463 -79.389644    M5V 1J5    ON
# 2                      35 Church St  43.648824 -79.373702    M5E 1T3    ON
# 3               37 King Street East  43.649298 -79.376431    M5C 1E9    ON
# 4                  353 Spadina Ave.  43.655337 -79.398897    M5T 2G3    ON
# 5                988 Baldwin Street  43.655874 -79.393826        NaN    ON
# 6                    476 Dundas St.  43.653185 -79.396677        NaN    ON
# 7                  30 Mercer Street  43.645634 -79.391125    M5V 1H3    ON
# 8                  280 Spadina Ave.  43.652783 -79.398174        NaN    ON
# 9                    389 Church St.  43.661500 -79.379319        M5B    ON
# 10                   225 Front St W  43.644749 -79.385113    M5V 2X3    ON
# 11  261 Spadina Avenue. Upper level  43.652488 -79.397501    M5T 2E3    ON
# 12                  266 Spadina Ave  43.652278 -79.398039    M5T 2E4    ON
# 13                 309 Spadina Ave.  43.653866 -79.398334    M5T 2E6    ON
# 14                  8 St Andrew St.  43.654307 -79.399277    M5T 1K6    ON
# 15                   301 Front St W  43.642537 -79.387042    M5V 2T6    ON
# 16                 323 Spadina Ave.  43.654318 -79.398650    M5T 2E9    ON
# 17                   338 Jarvis St.  43.662770 -79.376894    M4Y 2G6    ON
# 18                  405 Spadina Ave  43.656794 -79.399251    M5T 2G6    ON
# 19                  1 Blue Jays Way  43.641479 -79.389074    M5V 1J4    ON
# 20               2A Kensington Ave.  43.652803 -79.399958    M5T 2J7    ON
# 21                    Rogers Centre  43.641635 -79.389365        NaN    ON
# 22          325 Bay St (31st floor)  43.649563 -79.380590        M5H    ON
# 23                   566 Queen St W  43.647289 -79.403493        NaN    ON
# 24                  108 Dundas St W  43.655655 -79.384124    M5G 1C3    ON
# 25                126 Elizabeth St.  43.655281 -79.385337        NaN    ON
# 26                  430 College St.  43.656673 -79.407101    M5T 1T3    ON
# 27            100 Cumberland Street  43.670342 -79.391041    M5R 1A6    ON
# 28              143 Dundas St. West  43.655381 -79.385270        NaN    ON
# 29              293 Palmerston Ave.  43.655765 -79.409929    M6J 2J3    ON

# %%
# delete rows with none values
df_Restaurant = clean_Restaurant_dataframe2.dropna(axis=0, how='any', thresh=None, subset=None, inplace=False)
df_Restaurant
# Out:
#                                               name               categories  \
# 0                  Hemispheres Restaurant & Bistro      American Restaurant
# 1                     Aroma Fine Indian Restaurant        Indian Restaurant
# 2                   The Hot House Restaurant & Bar      American Restaurant
# 3                            Victoria's Restaurant               Restaurant
# 4                         New Sky Restaurant 小沙田食家       Chinese Restaurant
# 7                          Victor Restaurant & Bar                      Bar
# 9                                Studio Restaurant           Breakfast Spot
# 10                          Azure Restaurant & Bar               Restaurant
# 11                   Green Tea Restaurant Downtown       Chinese Restaurant
# 12                  Goldstone Noodle Restaurant 金石             Noodle House
# 13                         Swatow Restaurant 汕頭小食家       Chinese Restaurant
# 14                        Ka Chi Korean Restaurant        Korean Restaurant
# 15                                  360 Restaurant                 Wine Bar
# 16                          Rol San Restaurant 龍笙棧       Dim Sum Restaurant
# 17                     Cottage Restaurant & Lounge          Thai Restaurant
# 18         Tasty's Caribbean Restaurant & Catering     Caribbean Restaurant
# 19                               Arriba Restaurant               Restaurant
# 20               Kensington Cornerstone Restaurant           Breakfast Spot
# 22                           Restaurant | Adelaide               Restaurant
# 24                      Alio Restaurant & Wine Bar       Italian Restaurant
# 26               El Rancho Restaurant & Night Club                Nightclub
# 27  Sassafraz | Cafe | Restaurant | Private Events              Event Space
# 29                     Woodlot Restaurant & Bakery  New American Restaurant
#
#                             address        lat        lng postalCode state
# 0               110 Chestnut Street  43.654884 -79.385931    M5G 1R3    ON
# 1                    287 King St. W  43.646463 -79.389644    M5V 1J5    ON
# 2                      35 Church St  43.648824 -79.373702    M5E 1T3    ON
# 3               37 King Street East  43.649298 -79.376431    M5C 1E9    ON
# 4                  353 Spadina Ave.  43.655337 -79.398897    M5T 2G3    ON
# 7                  30 Mercer Street  43.645634 -79.391125    M5V 1H3    ON
# 9                    389 Church St.  43.661500 -79.379319        M5B    ON
# 10                   225 Front St W  43.644749 -79.385113    M5V 2X3    ON
# 11  261 Spadina Avenue. Upper level  43.652488 -79.397501    M5T 2E3    ON
# 12                  266 Spadina Ave  43.652278 -79.398039    M5T 2E4    ON
# 13                 309 Spadina Ave.  43.653866 -79.398334    M5T 2E6    ON
# 14                  8 St Andrew St.  43.654307 -79.399277    M5T 1K6    ON
# 15                   301 Front St W  43.642537 -79.387042    M5V 2T6    ON
# 16                 323 Spadina Ave.  43.654318 -79.398650    M5T 2E9    ON
# 17                   338 Jarvis St.  43.662770 -79.376894    M4Y 2G6    ON
# 18                  405 Spadina Ave  43.656794 -79.399251    M5T 2G6    ON
# 19                  1 Blue Jays Way  43.641479 -79.389074    M5V 1J4    ON
# 20               2A Kensington Ave.  43.652803 -79.399958    M5T 2J7    ON
# 22          325 Bay St (31st floor)  43.649563 -79.380590        M5H    ON
# 24                  108 Dundas St W  43.655655 -79.384124    M5G 1C3    ON
# 26                  430 College St.  43.656673 -79.407101    M5T 1T3    ON
# 27            100 Cumberland Street  43.670342 -79.391041    M5R 1A6    ON
# 29              293 Palmerston Ave.  43.655765 -79.409929    M6J 2J3    ON

# %% [markdown]
# ## **Search for Cafeteria**

# %%
# search for Cafeteria
search_query = 'Cafeteria'
radius = 10000

# Define the corresponding URL
url = 'https://api.foursquare.com/v2/venues/search?client_id={}&client_secret={}&ll={},{}&v={}&query={}&radius={}&limit={}'.format(ClIENT_ID, ClIENT_SECRET, latitude, longitude, VERSION, search_query, radius, LIMIT)
url
# Out:
# 'https://api.foursquare.com/v2/venues/search?client_id=4FQQJE2LMGVLERRRE2BOFR1LQQR5ZEHFLTD1WRAFKOFT4TI0&client_secret=RCSNR5TH31NQRG2QYCHK101HRMTUZHBB2TSJ1CJU5UOGRXRQ&ll=43.6534817,-79.3839347&v=20180604&query=Cafeteria&radius=10000&limit=30'

# %%
# Send the GET Request and examine the results
cresults = requests.get(url).json()
#cresults

# %%
# assign relevant part of JSON to venues
venues = cresults['response']['venues']

# tranform venues into a dataframe
Cafeteria_dataframe = pd.json_normalize(venues)
Cafeteria_dataframe.head()
# Out:
#                          id                           name  \
# 0  4f9165bde4b04fef0087e4e2                      Cafeteria
# 1  528e99a211d262edc3708a6f              Stay Cafeteria 慢走
# 2  4b57256bf964a520332828e3                Sears Cafeteria
# 3  53bd6dfe498e6c1d3bc9333e  Industrial Alliance Cafeteria
# 4  524f1c8f498e983dde61ada0        Chestnut Tree Cafeteria
#
#                                           categories    referralId  hasPerk  \
# 0  [{'id': '4bf58dd8d48988d16e941735', 'name': 'F...  v-1587778292    False
# 1  [{'id': '4bf58dd8d48988d142941735', 'name': 'A...  v-1587778292    False
# 2  [{'id': '4bf58dd8d48988d120951735', 'name': 'F...  v-1587778292    False
# 3  [{'id': '4bf58dd8d48988d128941735', 'name': 'C...  v-1587778292    False
# 4  [{'id': '4bf58dd8d48988d128941735', 'name': 'C...  v-1587778292    False
#
#                             location.address  location.lat  location.lng  \
# 0  The Hospital for Sick Children (SickKids)     43.657209    -79.386063
# 1                            388 Spadina Ave     43.655454    -79.399163
# 2                                      Yonge     43.656038    -79.380672
# 3                                        NaN     43.655657    -79.389443
# 4                         89 Chestnut Street     43.648231    -79.384045
#
#                              location.labeledLatLngs  location.distance  \
# 0  [{'label': 'display', 'lat': 43.65720930549997...                448
# 1  [{'label': 'display', 'lat': 43.65545427446646...               1246
# 2  [{'label': 'display', 'lat': 43.65603785909391...                387
# 3  [{'label': 'display', 'lat': 43.655657, 'lng':...                505
# 4  [{'label': 'display', 'lat': 43.648231, 'lng':...                584
#
#   location.cc location.city location.state location.country  \
# 0          CA       Toronto             ON           Canada
# 1          CA       Toronto             ON           Canada
# 2          CA       Toronto             ON           Canada
# 3          CA       Toronto             ON           Canada
# 4          CA       Toronto             ON           Canada
#
#                            location.formattedAddress location.crossStreet  \
# 0  [The Hospital for Sick Children (SickKids), To...                  NaN
# 1  [388 Spadina Ave (at Nassau St), Toronto ON M5...         at Nassau St
# 2               [Yonge (Dundas), Toronto ON, Canada]               Dundas
# 3                               [Toronto ON, Canada]                  NaN
# 4           [89 Chestnut Street, Toronto ON, Canada]                  NaN
#
#   location.postalCode
# 0                 NaN
# 1             M5T 2G5
# 2                 NaN
# 3                 NaN
# 4                 NaN

# %% [markdown]
# ## **Clean Cafeteria Dataframe**

# %%
# keep only columns that include venue name, and anything that is associated with location
Cafeteria_clean_columns = ['name', 'categories'] + [col for col in Cafeteria_dataframe.columns if col.startswith('location.')]+ ['id']
clean_Cafeteria_dataframe = Cafeteria_dataframe.loc[:,Cafeteria_clean_columns]

# function that extracts the category of the venue
def get_category_type(row):
    try:
        categories_list4 = row['categories']
    except:
        categories_list4 = row['venue.categories']
        
    if len(categories_list4) == 0:
        return None
    else:
        return categories_list4[0]['name']

# filter the category for each row
clean_Cafeteria_dataframe['categories'] = clean_Cafeteria_dataframe.apply(get_category_type, axis=1)

# clean column names by keeping only last term
clean_Cafeteria_dataframe.columns = [column.split('.')[-1] for column in clean_Cafeteria_dataframe.columns]

clean_Cafeteria_dataframe.head()
# Out:
#                             name            categories  \
# 0                      Cafeteria  Fast Food Restaurant
# 1              Stay Cafeteria 慢走      Asian Restaurant
# 2                Sears Cafeteria            Food Court
# 3  Industrial Alliance Cafeteria             Cafeteria
# 4        Chestnut Tree Cafeteria             Cafeteria
#
#                                      address        lat        lng  \
# 0  The Hospital for Sick Children (SickKids)  43.657209 -79.386063
# 1                            388 Spadina Ave  43.655454 -79.399163
# 2                                      Yonge  43.656038 -79.380672
# 3                                        NaN  43.655657 -79.389443
# 4                         89 Chestnut Street  43.648231 -79.384045
#
#                                       labeledLatLngs  distance  cc     city  \
# 0  [{'label': 'display', 'lat': 43.65720930549997...       448  CA  Toronto
# 1  [{'label': 'display', 'lat': 43.65545427446646...      1246  CA  Toronto
# 2  [{'label': 'display', 'lat': 43.65603785909391...       387  CA  Toronto
# 3  [{'label': 'display', 'lat': 43.655657, 'lng':...       505  CA  Toronto
# 4  [{'label': 'display', 'lat': 43.648231, 'lng':...       584  CA  Toronto
#
#   state country                                   formattedAddress  \
# 0    ON  Canada  [The Hospital for Sick Children (SickKids), To...
# 1    ON  Canada  [388 Spadina Ave (at Nassau St), Toronto ON M5...
# 2    ON  Canada               [Yonge (Dundas), Toronto ON, Canada]
# 3    ON  Canada                               [Toronto ON, Canada]
# 4    ON  Canada           [89 Chestnut Street, Toronto ON, Canada]
#
#     crossStreet postalCode                        id
# 0           NaN        NaN  4f9165bde4b04fef0087e4e2
# 1  at Nassau St    M5T 2G5  528e99a211d262edc3708a6f
# 2        Dundas        NaN  4b57256bf964a520332828e3
# 3           NaN        NaN  53bd6dfe498e6c1d3bc9333e
# 4           NaN        NaN  524f1c8f498e983dde61ada0

# %%
# delete unnecessary columns
clean_Cafeteria_dataframe2= clean_Cafeteria_dataframe.drop(['cc', 'city', 'country', 'crossStreet', 'distance', 'formattedAddress',\
                                        'labeledLatLngs', 'id'], axis=1)
clean_Cafeteria_dataframe2
# Out:
#                                      name            categories  \
# 0                               Cafeteria  Fast Food Restaurant
# 1                       Stay Cafeteria 慢走      Asian Restaurant
# 2                         Sears Cafeteria            Food Court
# 3           Industrial Alliance Cafeteria             Cafeteria
# 4                 Chestnut Tree Cafeteria             Cafeteria
# 5                         Dears Cafeteria          Dessert Shop
# 6                          OCAD Cafeteria     College Cafeteria
# 7                   Ryerson Hub Cafeteria     College Cafeteria
# 8                      SickKids Cafeteria            Food Court
# 9           De La Salle College Cafeteria     College Cafeteria
# 10                      Med Sci Cafeteria     College Cafeteria
# 11              Macdonald Block Cafeteria             Cafeteria
# 12                      Robarts Cafeteria     College Cafeteria
# 13                          OMP Cafeteria             Cafeteria
# 14                       Rogers Cafeteria            Food Court
# 15                      Choices Cafeteria            Food Court
# 16    Cafeteria, Lawrence Park Collegiate           High School
# 17    Cafeteria, Lawrence Park Collegiate           Event Space
# 18                             Marketeria            Restaurant
# 19                       Kasala Cafeteria    African Restaurant
# 20               Estonian House Cafeteria                  Café
# 21                                The Hub     College Cafeteria
# 22                           CC Cafeteria     College Cafeteria
# 23                          Innis College        Student Center
# 24                             Radio Cafe            Food Court
# 25  George Brown College St. James Campus     Community College
# 26     Lawrence Park Collegiate Cafeteria           High School
# 27                           L5 Cafeteria      Cuban Restaurant
# 28  6th Floor Cafeteria 12 Concorde Place                  Café
# 29                      Glendon Cafeteria     College Cafeteria
#
#                                       address        lat        lng state  \
# 0   The Hospital for Sick Children (SickKids)  43.657209 -79.386063    ON
# 1                             388 Spadina Ave  43.655454 -79.399163    ON
# 2                                       Yonge  43.656038 -79.380672    ON
# 3                                         NaN  43.655657 -79.389443    ON
# 4                          89 Chestnut Street  43.648231 -79.384045    ON
# 5                                         NaN  43.654179 -79.392555   NaN
# 6                              100 McCaul St.  43.652780 -79.391762    ON
# 7                            350 Victoria St.  43.658475 -79.377653    ON
# 8                       555 University Avenue  43.657584 -79.375652    ON
# 9                          131 Farnham Avenue  43.683003 -79.397815    ON
# 10                                        NaN  43.660260 -79.392977    ON
# 11                                        NaN  43.663212 -79.388062   NaN
# 12                         130 St. George St.  43.664864 -79.399766    ON
# 13                           1 Mount Pleasant  43.669801 -79.379790    ON
# 14                                        NaN  43.669904 -79.379748    ON
# 15                         200 Bloor Street E  43.671411 -79.381849    ON
# 16                                        NaN  43.721732 -79.409600   NaN
# 17                                        NaN  43.723286 -79.412222   NaN
# 18                                30 Bond St.  43.653585 -79.378843    ON
# 19                                      Bloor  43.660759 -79.424018   NaN
# 20                       958 Broadview avenue  43.681763 -79.358246    ON
# 21                           350 Victoria St.  43.658585 -79.380622    ON
# 22                             951 Carlaw Ave  43.684631 -79.348862    ON
# 23                               2 Sussex Ave  43.665556 -79.399298    ON
# 24                          333 Bloor st east  43.671696 -79.380617    ON
# 25                          200 King St. East  43.651366 -79.370158    ON
# 26                                        NaN  43.722757 -79.413734    ON
# 27                                        NaN  43.723019 -79.345012   NaN
# 28                          12 Concorde Place  43.721861 -79.329339    ON
# 29                           2275 Bayview Ave  43.727383 -79.378080    ON
#
#    postalCode
# 0         NaN
# 1     M5T 2G5
# 2         NaN
# 3         NaN
# 4         NaN
# 5         NaN
# 6         NaN
# 7         NaN
# 8         NaN
# 9     M4V 1H7
# 10        NaN
# 11        NaN
# 12        NaN
# 13        NaN
# 14        NaN
# 15        NaN
# 16        NaN
# 17        NaN
# 18    M5B 1W8
# 19        NaN
# 20        NaN
# 21    M5B 2K3
# 22        NaN
# 23    M5S 1J5
# 24        NaN
# 25        NaN
# 26        NaN
# 27        NaN
# 28    m3c 3k7
# 29        NaN

# %%
# delete rows with none values
df_Cafeteria = clean_Cafeteria_dataframe2.dropna(axis=0, how='any', thresh=None, subset=None, inplace=False)
df_Cafeteria
# Out:
#                                      name         categories  \
# 1                       Stay Cafeteria 慢走   Asian Restaurant
# 9           De La Salle College Cafeteria  College Cafeteria
# 18                             Marketeria         Restaurant
# 21                                The Hub  College Cafeteria
# 23                          Innis College     Student Center
# 28  6th Floor Cafeteria 12 Concorde Place               Café
#
#                address        lat        lng state postalCode
# 1      388 Spadina Ave  43.655454 -79.399163    ON    M5T 2G5
# 9   131 Farnham Avenue  43.683003 -79.397815    ON    M4V 1H7
# 18         30 Bond St.  43.653585 -79.378843    ON    M5B 1W8
# 21    350 Victoria St.  43.658585 -79.380622    ON    M5B 2K3
# 23        2 Sussex Ave  43.665556 -79.399298    ON    M5S 1J5
# 28   12 Concorde Place  43.721861 -79.329339    ON    m3c 3k7

# %% [markdown]
# ## **Search for Shopping Stores**

# %%
# search for Shopping
search_query = 'Shopping'
radius = 1000

# Define the corresponding URL
url = 'https://api.foursquare.com/v2/venues/search?client_id={}&client_secret={}&ll={},{}&v={}&query={}&radius={}&limit={}'.format(ClIENT_ID, ClIENT_SECRET, latitude, longitude, VERSION, search_query, radius, LIMIT)
url
# Out:
# 'https://api.foursquare.com/v2/venues/search?client_id=4FQQJE2LMGVLERRRE2BOFR1LQQR5ZEHFLTD1WRAFKOFT4TI0&client_secret=RCSNR5TH31NQRG2QYCHK101HRMTUZHBB2TSJ1CJU5UOGRXRQ&ll=43.6534817,-79.3839347&v=20180604&query=Shopping&radius=1000&limit=30'

# %%
# Send the GET Request and examine the results
sresults = requests.get(url).json()
#sresults

# %%
# assign relevant part of JSON to venues
venues = sresults['response']['venues']

# tranform venues into a dataframe
Shopping_dataframe = pd.json_normalize(venues)
Shopping_dataframe.head()
# Out:
#                          id                                        name  \
# 0  5840cafe06f1a34af80cc609  Saks Fifth Avenue Club - Personal Shopping
# 1  4ad77a12f964a520260b21e3                     CF Toronto Eaton Centre
# 2  4b9e86dff964a520e6eb36e3                TD Centre Shopping Concourse
#
#                                           categories    referralId  hasPerk  \
# 0  [{'id': '4bf58dd8d48988d1f6941735', 'name': 'D...  v-1587778365    False
# 1  [{'id': '4bf58dd8d48988d1fd941735', 'name': 'S...  v-1587778365    False
# 2  [{'id': '4bf58dd8d48988d1fd941735', 'name': 'S...  v-1587778365    False
#
#      location.address location.crossStreet  location.lat  location.lng  \
# 0    176 Yonge Street    Queen Street West     43.651810    -79.379192
# 1        220 Yonge St  btwn Queen & Dundas     43.654540    -79.380677
# 2  66 Wellington St W    btw York & Bay St     43.647184    -79.380932
#
#                              location.labeledLatLngs  location.distance  \
# 0  [{'label': 'display', 'lat': 43.65181, 'lng': ...                424
# 1                                                NaN                287
# 2  [{'label': 'display', 'lat': 43.64718424611984...                741
#
#   location.postalCode location.cc location.city location.state  \
# 0             M5C 2L7          CA       Toronto             ON
# 1             M5B 2H1          CA       Toronto             ON
# 2             M5K 1A1          CA       Toronto             ON
#
#   location.country                          location.formattedAddress  \
# 0           Canada  [176 Yonge Street (Queen Street West), Toronto...
# 1           Canada  [220 Yonge St (btwn Queen & Dundas), Toronto O...
# 2           Canada  [66 Wellington St W (btw York & Bay St), Toron...
#
#            location.neighborhood
# 0                            NaN
# 1  Downtown Toronto, Toronto, ON
# 2                            NaN

# %% [markdown]
# ## **Clean Shopping Dataframe**

# %%
# keep only columns that include venue name, and anything that is associated with location
Shopping_clean_columns = ['name', 'categories'] + [col for col in Shopping_dataframe.columns if col.startswith('location.')]+ ['id']
clean_Shopping_dataframe = Shopping_dataframe.loc[:,Shopping_clean_columns]

# function that extracts the category of the venue
def get_category_type(row):
    try:
        categories_list5 = row['categories']
    except:
        categories_list5 = row['venue.categories']
        
    if len(categories_list5) == 0:
        return None
    else:
        return categories_list5[0]['name']

# filter the category for each row
clean_Shopping_dataframe['categories'] = clean_Shopping_dataframe.apply(get_category_type, axis=1)

# clean column names by keeping only last term
clean_Shopping_dataframe.columns = [column.split('.')[-1] for column in clean_Shopping_dataframe.columns]

clean_Shopping_dataframe.head()
# Out:
#                                          name        categories  \
# 0  Saks Fifth Avenue Club - Personal Shopping  Department Store
# 1                     CF Toronto Eaton Centre     Shopping Mall
# 2                TD Centre Shopping Concourse     Shopping Mall
#
#               address          crossStreet        lat        lng  \
# 0    176 Yonge Street    Queen Street West  43.651810 -79.379192
# 1        220 Yonge St  btwn Queen & Dundas  43.654540 -79.380677
# 2  66 Wellington St W    btw York & Bay St  43.647184 -79.380932
#
#                                       labeledLatLngs  distance postalCode  cc  \
# 0  [{'label': 'display', 'lat': 43.65181, 'lng': ...       424    M5C 2L7  CA
# 1                                                NaN       287    M5B 2H1  CA
# 2  [{'label': 'display', 'lat': 43.64718424611984...       741    M5K 1A1  CA
#
#       city state country                                   formattedAddress  \
# 0  Toronto    ON  Canada  [176 Yonge Street (Queen Street West), Toronto...
# 1  Toronto    ON  Canada  [220 Yonge St (btwn Queen & Dundas), Toronto O...
# 2  Toronto    ON  Canada  [66 Wellington St W (btw York & Bay St), Toron...
#
#                     neighborhood                        id
# 0                            NaN  5840cafe06f1a34af80cc609
# 1  Downtown Toronto, Toronto, ON  4ad77a12f964a520260b21e3
# 2                            NaN  4b9e86dff964a520e6eb36e3

# %%
# delete unnecessary columns
clean_Shopping_dataframe2= clean_Shopping_dataframe.drop(['cc', 'city', 'country', 'crossStreet', 'distance', 'formattedAddress',\
                                        'labeledLatLngs', 'neighborhood', 'id'], axis=1)
clean_Shopping_dataframe2
# Out:
#                                          name        categories  \
# 0  Saks Fifth Avenue Club - Personal Shopping  Department Store
# 1                     CF Toronto Eaton Centre     Shopping Mall
# 2                TD Centre Shopping Concourse     Shopping Mall
#
#               address        lat        lng postalCode state
# 0    176 Yonge Street  43.651810 -79.379192    M5C 2L7    ON
# 1        220 Yonge St  43.654540 -79.380677    M5B 2H1    ON
# 2  66 Wellington St W  43.647184 -79.380932    M5K 1A1    ON

# %%
# delete rows which its category is not Shopping Mall
df_Shopping = clean_Shopping_dataframe2[clean_Shopping_dataframe2.categories == 'Shopping Mall']
df_Shopping
# Out:
#                            name     categories             address        lat  \
# 1       CF Toronto Eaton Centre  Shopping Mall        220 Yonge St  43.654540
# 2  TD Centre Shopping Concourse  Shopping Mall  66 Wellington St W  43.647184
#
#          lng postalCode state
# 1 -79.380677    M5B 2H1    ON
# 2 -79.380932    M5K 1A1    ON

# %% [markdown]
# ## **Generate maps to visualize venues and how they cluster together**

# %% [markdown]
# ### **Create dataframe of hotels, shopping stores and Cafeteria**

# %%
# create dataframe of hotels, shopping stores and Cafeteria
hotel_neighbourhood_df = pd.concat([df_hotel, df_Cafeteria, df_Shopping ], ignore_index=True)
hotel_neighbourhood_df
# Out:
#                                     name         categories  \
# 0          Sheraton Centre Toronto Hotel              Hotel
# 1                         Grand Ballroom        Event Space
# 2                      Stay Cafeteria 慢走   Asian Restaurant
# 3          De La Salle College Cafeteria  College Cafeteria
# 4                             Marketeria         Restaurant
# 5                                The Hub  College Cafeteria
# 6                          Innis College     Student Center
# 7  6th Floor Cafeteria 12 Concorde Place               Café
# 8                CF Toronto Eaton Centre      Shopping Mall
# 9           TD Centre Shopping Concourse      Shopping Mall
#
#                  address        lat        lng postalCode state
# 0  123 Queen Street West  43.650594 -79.384530    M5H 2M9    ON
# 1        123 Queen St. W  43.651217 -79.383771    M5H 2M9    ON
# 2        388 Spadina Ave  43.655454 -79.399163    M5T 2G5    ON
# 3     131 Farnham Avenue  43.683003 -79.397815    M4V 1H7    ON
# 4            30 Bond St.  43.653585 -79.378843    M5B 1W8    ON
# 5       350 Victoria St.  43.658585 -79.380622    M5B 2K3    ON
# 6           2 Sussex Ave  43.665556 -79.399298    M5S 1J5    ON
# 7      12 Concorde Place  43.721861 -79.329339    m3c 3k7    ON
# 8           220 Yonge St  43.654540 -79.380677    M5B 2H1    ON
# 9     66 Wellington St W  43.647184 -79.380932    M5K 1A1    ON

# %% [markdown]
# ### **Generate map to visualize hotel neighbourhood including shopping stores and Cafeteria**

# %%
# Generate map to visualize hotel neighbourhood including shopping stores and Cafeteria 
hotel_map = folium.Map(location=[latitude, longitude], zoom_start=14)

for lat, lng, name, categories, address in zip(hotel_neighbourhood_df['lat'], hotel_neighbourhood_df['lng'], 
                                           hotel_neighbourhood_df['name'], hotel_neighbourhood_df['categories'],\
                                               hotel_neighbourhood_df['address']):
    label = '{}, {}'.format(name, address)
    label = folium.Popup(label, parse_html=True)
    folium.CircleMarker(
        [lat, lng],
        radius=5,
        popup=label,
        color='blue',
        fill=True,
        fill_color='pink',
        fill_opacity=0.7,
        parse_html=False).add_to(hotel_map)  
    
hotel_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=... onload="this.contentDocument.open();this.contentDocument.write(atob(this.getAttribute('data-html')));this.contentDocument.close();" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# ### **Create dataframe of Park, Restaurant and Cafeteria**

# %%
# create dataframe of Park, Restaurant and Cafeteria
park_neighbourhood_df = pd.concat([df_park, df_Restaurant, df_Cafeteria,], ignore_index=True)
park_neighbourhood_df
# Out:
#                                               name               categories  \
# 0                                     Queen's Park                     Park
# 1                              Riverdale Park West                     Park
# 2                           Trinity Bellwoods Park                     Park
# 3                              Riverdale Park East                     Park
# 4                                Barbara Hall Park                     Park
# 5                             Bellevue Square Park                     Park
# 6                  Hemispheres Restaurant & Bistro      American Restaurant
# 7                     Aroma Fine Indian Restaurant        Indian Restaurant
# 8                   The Hot House Restaurant & Bar      American Restaurant
# 9                            Victoria's Restaurant               Restaurant
# 10                        New Sky Restaurant 小沙田食家       Chinese Restaurant
# 11                         Victor Restaurant & Bar                      Bar
# 12                               Studio Restaurant           Breakfast Spot
# 13                          Azure Restaurant & Bar               Restaurant
# 14                   Green Tea Restaurant Downtown       Chinese Restaurant
# 15                  Goldstone Noodle Restaurant 金石             Noodle House
# 16                         Swatow Restaurant 汕頭小食家       Chinese Restaurant
# 17                        Ka Chi Korean Restaurant        Korean Restaurant
# 18                                  360 Restaurant                 Wine Bar
# 19                          Rol San Restaurant 龍笙棧       Dim Sum Restaurant
# 20                     Cottage Restaurant & Lounge          Thai Restaurant
# 21         Tasty's Caribbean Restaurant & Catering     Caribbean Restaurant
# 22                               Arriba Restaurant               Restaurant
# 23               Kensington Cornerstone Restaurant           Breakfast Spot
# 24                           Restaurant | Adelaide               Restaurant
# 25                      Alio Restaurant & Wine Bar       Italian Restaurant
# 26               El Rancho Restaurant & Night Club                Nightclub
# 27  Sassafraz | Cafe | Restaurant | Private Events              Event Space
# 28                     Woodlot Restaurant & Bakery  New American Restaurant
# 29                               Stay Cafeteria 慢走         Asian Restaurant
# 30                   De La Salle College Cafeteria        College Cafeteria
# 31                                      Marketeria               Restaurant
# 32                                         The Hub        College Cafeteria
# 33                                   Innis College           Student Center
# 34           6th Floor Cafeteria 12 Concorde Place                     Café
#
#                             address        lat        lng postalCode state
# 0                   University Ave.  43.663946 -79.392180    M5R 2E8    ON
# 1                   500 Gerrard St.  43.666048 -79.360941    M5A 2H3    ON
# 2                1053 Dundas St. W.  43.647072 -79.413756    M5H 2N2    ON
# 3                 550 Broadview Ave  43.669951 -79.355493    M4K 2P1    ON
# 4                     519 Church St  43.666879 -79.381068    M4Y 2K9    ON
# 5      btwn Bellevue & Augusta Ave.  43.653610 -79.402199    M5T 2N4    ON
# 6               110 Chestnut Street  43.654884 -79.385931    M5G 1R3    ON
# 7                    287 King St. W  43.646463 -79.389644    M5V 1J5    ON
# 8                      35 Church St  43.648824 -79.373702    M5E 1T3    ON
# 9               37 King Street East  43.649298 -79.376431    M5C 1E9    ON
# 10                 353 Spadina Ave.  43.655337 -79.398897    M5T 2G3    ON
# 11                 30 Mercer Street  43.645634 -79.391125    M5V 1H3    ON
# 12                   389 Church St.  43.661500 -79.379319        M5B    ON
# 13                   225 Front St W  43.644749 -79.385113    M5V 2X3    ON
# 14  261 Spadina Avenue. Upper level  43.652488 -79.397501    M5T 2E3    ON
# 15                  266 Spadina Ave  43.652278 -79.398039    M5T 2E4    ON
# 16                 309 Spadina Ave.  43.653866 -79.398334    M5T 2E6    ON
# 17                  8 St Andrew St.  43.654307 -79.399277    M5T 1K6    ON
# 18                   301 Front St W  43.642537 -79.387042    M5V 2T6    ON
# 19                 323 Spadina Ave.  43.654318 -79.398650    M5T 2E9    ON
# 20                   338 Jarvis St.  43.662770 -79.376894    M4Y 2G6    ON
# 21                  405 Spadina Ave  43.656794 -79.399251    M5T 2G6    ON
# 22                  1 Blue Jays Way  43.641479 -79.389074    M5V 1J4    ON
# 23               2A Kensington Ave.  43.652803 -79.399958    M5T 2J7    ON
# 24          325 Bay St (31st floor)  43.649563 -79.380590        M5H    ON
# 25                  108 Dundas St W  43.655655 -79.384124    M5G 1C3    ON
# 26                  430 College St.  43.656673 -79.407101    M5T 1T3    ON
# 27            100 Cumberland Street  43.670342 -79.391041    M5R 1A6    ON
# 28              293 Palmerston Ave.  43.655765 -79.409929    M6J 2J3    ON
# 29                  388 Spadina Ave  43.655454 -79.399163    M5T 2G5    ON
# 30               131 Farnham Avenue  43.683003 -79.397815    M4V 1H7    ON
# 31                      30 Bond St.  43.653585 -79.378843    M5B 1W8    ON
# 32                 350 Victoria St.  43.658585 -79.380622    M5B 2K3    ON
# 33                     2 Sussex Ave  43.665556 -79.399298    M5S 1J5    ON
# 34                12 Concorde Place  43.721861 -79.329339    m3c 3k7    ON

# %% [markdown]
# ### **Generate map to visualize park neighbourhood including Restaurant and Cafeteria**

# %%
# Generate map to visualize park neighbourhood including Restaurant and Cafeteria 
park_map = folium.Map(location=[latitude, longitude], zoom_start=14)

for lat, lng, name, categories, address in zip(park_neighbourhood_df['lat'], park_neighbourhood_df['lng'], 
                                           park_neighbourhood_df['name'], park_neighbourhood_df['categories'],\
                                               park_neighbourhood_df['address']):
    label = '{}, {}'.format(name, address)
    label = folium.Popup(label, parse_html=True)
    folium.CircleMarker(
        [lat, lng],
        radius=5,
        popup=label,
        color='blue',
        fill=True,
        fill_color='red',
        fill_opacity=0.7,
        parse_html=False).add_to(park_map)  
    
park_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=... onload="this.contentDocument.open();this.contentDocument.write(atob(this.getAttribute('data-html')));this.contentDocument.close();" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>
